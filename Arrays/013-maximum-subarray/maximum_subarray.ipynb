# %% [markdown]
# # LeetCode 53: Maximum Subarray
#
# ## Problem Statement
# Given an integer array `nums`, find the contiguous subarray (containing at least one number) which has the largest sum and return its sum.
#
# ## Concept
# **Kadane's Algorithm** — track the maximum subarray sum ending at each position.
#
# ## Difficulty
# Medium
#
# ## Constraints
# - 1 <= len(nums) <= 10^5
# - -10^4 <= nums[i] <= 10^4
#
# ## Examples
# ```
# Input: nums = [-2,1,-3,4,-1,2,1,-5,4]
# Output: 6
# Explanation: The subarray [4,-1,2,1] has the largest sum 6.
# ```
# ```
# Input: nums = [1]
# Output: 1
# ```
# ```
# Input: nums = [-1,-2,-3]
# Output: -1
# ```

# %%
def max_sub_array(nums):
    """
    Finds the maximum sum of a contiguous subarray.
    
    Args:
        nums: List of integers
    
    Returns:
        int — the maximum subarray sum
    """
    # TODO: Implement your solution here
    return 0

# %%
# Test Cases

nums1 = [-2, 1, -3, 4, -1, 2, 1, -5, 4]
result1 = max_sub_array(nums1)
print(f"Test 1 - Input: [-2,1,-3,4,-1,2,1,-5,4]")
print(f"Expected: 6")
print(f"Got: {result1}")
print()

nums2 = [1]
result2 = max_sub_array(nums2)
print(f"Test 2 - Input: [1]")
print(f"Expected: 1")
print(f"Got: {result2}")
print()

nums3 = [-1, -2, -3]
result3 = max_sub_array(nums3)
print(f"Test 3 - Input: [-1,-2,-3]")
print(f"Expected: -1")
print(f"Got: {result3}")
