# %% [markdown]
# # LeetCode 15: 3Sum
#
# ## Problem Statement
# Given an integer array `nums`, return all the unique triplets `[nums[i], nums[j], nums[k]]` such that `i != j`, `i != k`, `j != k`, and `nums[i] + nums[j] + nums[k] == 0`.
#
# ## Concept
# **Two-Pointer** — sort the array, then fix one element and use two pointers to find pairs that complete the triplet.
#
# ## Difficulty
# Medium
#
# ## Constraints
# - 3 <= len(nums) <= 3000
# - -10^5 <= nums[i] <= 10^5
#
# ## Examples
# ```
# Input: nums = [-1,0,1,2,-1,-4]
# Output: [[-1,-1,2],[-1,0,1]]
# ```
# ```
# Input: nums = [0,1,1]
# Output: []
# ```
# ```
# Input: nums = [0,0,0]
# Output: [[0,0,0]]
# ```

# %%
def three_sum(nums):
    """
    Finds all unique triplets that sum to zero.
    
    Args:
        nums: List of integers
    
    Returns:
        List of lists, each containing a unique triplet
    """
    # TODO: Implement your solution here
    return []

# %%
# Test Cases

nums1 = [-1, 0, 1, 2, -1, -4]
result1 = three_sum(nums1)
print(f"Test 1 - Input: [-1,0,1,2,-1,-4]")
print(f"Expected: [[-1,-1,2],[-1,0,1]]")
print(f"Got: {result1}")
print()

nums2 = [0, 1, 1]
result2 = three_sum(nums2)
print(f"Test 2 - Input: [0,1,1]")
print(f"Expected: []")
print(f"Got: {result2}")
print()

nums3 = [0, 0, 0]
result3 = three_sum(nums3)
print(f"Test 3 - Input: [0,0,0]")
print(f"Expected: [[0,0,0]]")
print(f"Got: {result3}")
