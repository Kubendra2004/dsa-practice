# %% [markdown]
# # LeetCode 56: Merge Intervals
#
# ## Problem Statement
# Given an array of `intervals` where `intervals[i] = [starti, endi]`, merge all overlapping intervals, and return an array of the non-overlapping intervals that cover all the intervals in the input.
#
# ## Concept
# **Sort + Merge** — sort by start time, then merge overlapping intervals by extending the end boundary.
#
# ## Difficulty
# Medium
#
# ## Constraints
# - 1 <= intervals.length <= 10^4
# - intervals[i].length == 2
# - 0 <= starti <= endi <= 10^4
#
# ## Examples
# ```
# Input: intervals = [[1,3],[2,6],[8,10],[15,18]]
# Output: [[1,6],[8,10],[15,18]]
# ```
# ```
# Input: intervals = [[1,4],[4,5]]
# Output: [[1,5]]
# ```

# %%
def merge(intervals):
    """
    Merges overlapping intervals.
    
    Args:
        intervals: List of [start, end] pairs
    
    Returns:
        List of merged non-overlapping intervals
    """
    # TODO: Implement your solution here
    return []

# %%
# Test Cases

intervals1 = [[1, 3], [2, 6], [8, 10], [15, 18]]
result1 = merge(intervals1)
print(f"Test 1 - Input: [[1,3],[2,6],[8,10],[15,18]]")
print(f"Expected: [[1,6],[8,10],[15,18]]")
print(f"Got: {result1}")
print()

intervals2 = [[1, 4], [4, 5]]
result2 = merge(intervals2)
print(f"Test 2 - Input: [[1,4],[4,5]]")
print(f"Expected: [[1,5]]")
print(f"Got: {result2}")
print()

intervals3 = [[1, 2], [3, 4], [5, 6]]
result3 = merge(intervals3)
print(f"Test 3 - Input: [[1,2],[3,4],[5,6]]")
print(f"Expected: [[1,2],[3,4],[5,6]]")
print(f"Got: {result3}")
