# %% [markdown]
# # LeetCode 33: Search in Rotated Sorted Array
#
# ## Problem Statement
# There is an integer array `nums` sorted in ascending order (with distinct values). Before being passed to your function, `nums` is possibly rotated at an unknown pivot index `k`. Given `target`, return the index of `target` if it is in `nums`, or `-1` if it is not in `nums`.
#
# ## Concept
# **Binary Search** — determine which half is sorted and decide which side to search.
#
# ## Difficulty
# Medium
#
# ## Constraints
# - 1 <= nums.length <= 5000
# - -10^4 <= nums[i] <= 10^4
# - All values are unique
# - nums is guaranteed to be rotated at some pivot
#
# ## Examples
# ```
# Input: nums = [4,5,6,7,0,1,2], target = 0
# Output: 4
# ```
# ```
# Input: nums = [4,5,6,7,0,1,2], target = 3
# Output: -1
# ```

# %%
def search(nums, target):
    """
    Searches for target in rotated sorted array using binary search.
    
    Args:
        nums: List of integers (rotated sorted)
        target: Integer to find
    
    Returns:
        int — index of target, or -1 if not found
    """
    # TODO: Implement your solution here
    return -1

# %%
# Test Cases

nums1 = [4, 5, 6, 7, 0, 1, 2]
result1 = search(nums1, 0)
print(f"Test 1 - Input: [4,5,6,7,0,1,2], target=0")
print(f"Expected: 4")
print(f"Got: {result1}")
print()

nums2 = [4, 5, 6, 7, 0, 1, 2]
result2 = search(nums2, 3)
print(f"Test 2 - Input: [4,5,6,7,0,1,2], target=3")
print(f"Expected: -1")
print(f"Got: {result2}")
print()

nums3 = [1]
result3 = search(nums3, 0)
print(f"Test 3 - Input: [1], target=0")
print(f"Expected: -1")
print(f"Got: {result3}")
