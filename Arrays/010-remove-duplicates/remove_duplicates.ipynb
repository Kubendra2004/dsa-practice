# %% [markdown]
# # LeetCode 26: Remove Duplicates from Sorted Array
#
# ## Problem Statement
# Given a sorted array `nums`, remove the duplicates in-place such that each unique element appears only once. Return the number of unique elements.
#
# **Note:** Do not allocate extra space for another array. You must do this by modifying the input array in-place with O(1) extra memory.
#
# ## Concept
# **Two-Pointer Technique** — slow pointer tracks the position of the last unique element, fast pointer scans for the next unique element.
#
# ## Difficulty
# Easy
#
# ## Constraints
# - 1 ≤ len(nums) ≤ 3 × 10^4
# - -100 ≤ nums[i] ≤ 100
# - `nums` is sorted in non-decreasing order
#
# ## Examples
# ```
# Input: nums = [1,1,2]
# Output: 2, nums = [1,2,_]
# ```
# ```
# Input: nums = [0,0,0,0]
# Output: 1, nums = [0,_]
# ```

# %%
def remove_duplicates(nums):
    """
    Removes duplicates from a sorted array in-place.
    
    Args:
        nums: Sorted list of integers (modified in-place)
    
    Returns:
        int — the number of unique elements
    """
    # TODO: Implement your solution here
    write=1
    read=1
    while read<len(nums):
        if nums[read]!=nums[write-1]:
            nums[write]=nums[read]
            write+=1
        read+=1
    return write

# %%
# Test Cases

nums1 = [1, 1, 2]
k1 = remove_duplicates(nums1)
print(f"Test 1 - Input: [1,1,2]")
print(f"Expected: 2 (nums = [1,2,_])")
print(f"Got length: {k1}")
print(f"Got array: {nums1[:k1]}")
print()

nums2 = [0, 0, 0, 0]
k2 = remove_duplicates(nums2)
print(f"Test 2 - Input: [0,0,0,0]")
print(f"Expected: 1 (nums = [0,_])")
print(f"Got length: {k2}")
print(f"Got array: {nums2[:k2]}")
print()

nums3 = [1, 2, 3]
k3 = remove_duplicates(nums3)
print(f"Test 3 - Input: [1,2,3]")
print(f"Expected: 3 (nums = [1,2,3])")
print(f"Got length: {k3}")
print(f"Got array: {nums3[:k3]}")
# Out:
# Test 1 - Input: [1,1,2]
# Expected: 2 (nums = [1,2,_])
# Got length: 2
# Got array: [1, 2]
#
# Test 2 - Input: [0,0,0,0]
# Expected: 1 (nums = [0,_])
# Got length: 1
# Got array: [0]
#
# Test 3 - Input: [1,2,3]
# Expected: 3 (nums = [1,2,3])
# Got length: 3
# Got array: [1, 2, 3]
