# %% [markdown]
# # LeetCode 167: Two Sum II – Input Array Is Sorted
#
# ## Problem Statement
# Given a **sorted** integer array `numbers` and an integer `target`, return the **indices of the two numbers** (1-indexed, not 0-indexed) that add up to the target. You may assume each input has **exactly one solution** and you **cannot use the same element twice**.
#
# ## Concept
# **Two-pointer technique** — efficient pair finding in a sorted array
#
# ## Difficulty
# Easy
#
# ## Constraints
# - 2 ≤ len(numbers) ≤ 3 × 10⁴
# - -10⁹ ≤ numbers[i] ≤ 10⁹
# - numbers is sorted in non-decreasing order
# - -10⁹ ≤ target ≤ 10⁹
#
# ## Examples
# ```
# Input: numbers = [2, 7, 11, 15], target = 9
# Output: [1, 2]
# Explanation: numbers[1] + numbers[2] = 2 + 7 = 9. Return [1, 2] (1-indexed).
#
# Input: numbers = [2, 3, 4], target = 6
# Output: [1, 3]
# Explanation: numbers[1] + numbers[3] = 2 + 4 = 6. Return [1, 3].
# ```

# %%
def two_sum(numbers, target):
    """
    Finds the two numbers in a sorted array that add up to the target.
    
    Args:
        numbers: Sorted list of integers
        target: Target sum
    
    Returns:
        A 1-indexed list [index1, index2] where numbers[index1-1] + numbers[index2-1] = target
    """
    # TODO: Implement your solution here

    left=0;
    right=len(numbers)-1
    while(left<right):
        if (numbers[left]+numbers[right])==target:
            return [left,right]
        elif numbers[left]+numbers[right]<target:
            right-=1
        else:
            left+=1
    return False
        
    pass

# %%
# Test Cases

# Test 1: Standard case
numbers1 = [2, 7, 11, 15]
target1 = 9
print(f"Test 1 - Input: {numbers1}, target = {target1}")
print(f"Expected: [1, 2]")
print(f"Got: {two_sum(numbers1, target1)}")
print()

# Test 2: Second and third elements
numbers2 = [2, 3, 4]
target2 = 6
print(f"Test 2 - Input: {numbers2}, target = {target2}")
print(f"Expected: [1, 3]")
print(f"Got: {two_sum(numbers2, target2)}")
print()

# Test 3: Middle elements
numbers3 = [1, 2, 3, 4, 4, 9, 56, 90]
target3 = 13
print(f"Test 3 - Input: {numbers3}, target = {target3}")
print(f"Expected: [4, 6] (4 + 9 = 13)")
print(f"Got: {two_sum(numbers3, target3)}")
print()

# Test 4: Negative numbers
numbers4 = [-1, 0, 1, 2, 3]
target4 = 2
print(f"Test 4 - Input: {numbers4}, target = {target4}")
print(f"Expected: [2, 4] (0 + 2 = 2, or [-1] + [3] at indices [1, 5])")
print(f"Got: {two_sum(numbers4, target4)}")
# Out:
# Test 1 - Input: [2, 7, 11, 15], target = 9
# Expected: [1, 2]
# Got: False
#
# Test 2 - Input: [2, 3, 4], target = 6
# Expected: [1, 3]
# Got: [0, 2]
#
# Test 3 - Input: [1, 2, 3, 4, 4, 9, 56, 90], target = 13
# Expected: [4, 6] (4 + 9 = 13)
# Got: False
#
# Test 4 - Input: [-1, 0, 1, 2, 3], target = 2
# Expected: [2, 4] (0 + 2 = 2, or [-1] + [3] at indices [1, 5])
# Got: [0, 4]
