# %% [markdown]
# # LeetCode 238: Product of Array Except Self
#
# ## Problem Statement
# Given an integer array `nums`, return an array `answer` such that `answer[i]` is equal to the product of all the elements of `nums` except `nums[i]`.
#
# ## Concept
# **Prefix Product** — compute prefix products from the left and suffix products from the right, then multiply them.
#
# ## Difficulty
# Medium
#
# ## Constraints
# - 2 <= len(nums) <= 10^5
# - -30 <= nums[i] <= 30
# - The product of any prefix or suffix of nums fits in a 32-bit integer
#
# ## Examples
# ```
# Input: nums = [1,2,3,4]
# Output: [24,12,8,6]
# ```
# ```
# Input: nums = [-1,1,0,-3,3]
# Output: [0,0,9,0,0]
# ```

# %%
def product_except_self(nums):
    """
    Returns an array where each element is the product of all other elements.
    
    Args:
        nums: List of integers
    
    Returns:
        List of integers — products except self
    """
    # TODO: Implement your solution here
    return []

# %%
# Test Cases

nums1 = [1, 2, 3, 4]
result1 = product_except_self(nums1)
print(f"Test 1 - Input: [1,2,3,4]")
print(f"Expected: [24,12,8,6]")
print(f"Got: {result1}")
print()

nums2 = [-1, 1, 0, -3, 3]
result2 = product_except_self(nums2)
print(f"Test 2 - Input: [-1,1,0,-3,3]")
print(f"Expected: [0,0,9,0,0]")
print(f"Got: {result2}")
print()

nums3 = [2, 3]
result3 = product_except_self(nums3)
print(f"Test 3 - Input: [2,3]")
print(f"Expected: [3,2]")
print(f"Got: {result3}")
