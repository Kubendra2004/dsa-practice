# %% [markdown]
# # LeetCode 42: Trapping Rain Water
#
# ## Problem Statement
# Given `n` non-negative integers representing an elevation map where the width of each bar is 1, compute how much water it can trap after raining.
#
# ## Concept
# **Two-Pointer / Boundary** — track the maximum height from left and right, and use the smaller boundary to determine water at each position.
#
# ## Difficulty
# Hard
#
# ## Constraints
# - n == height.length
# - 0 <= n <= 3 * 10^4
# - 0 <= height[i] <= 10^5
#
# ## Examples
# ```
# Input: height = [0,1,0,2,1,0,1,3,2,1,2,1]
# Output: 6
# ```
# ```
# Input: height = [4,2,0,3,2,5]
# Output: 9
# ```

# %%
def trap(height):
    """
    Computes trapped water using two-pointer approach.
    
    Args:
        height: List of integers representing elevation map
    
    Returns:
        int — total trapped water units
    """
    # TODO: Implement your solution here
    return 0

# %%
# Test Cases

height1 = [0, 1, 0, 2, 1, 0, 1, 3, 2, 1, 2, 1]
result1 = trap(height1)
print(f"Test 1 - Input: [0,1,0,2,1,0,1,3,2,1,2,1]")
print(f"Expected: 6")
print(f"Got: {result1}")
print()

height2 = [4, 2, 0, 3, 2, 5]
result2 = trap(height2)
print(f"Test 2 - Input: [4,2,0,3,2,5]")
print(f"Expected: 9")
print(f"Got: {result2}")
print()

height3 = []
result3 = trap(height3)
print(f"Test 3 - Input: []")
print(f"Expected: 0")
print(f"Got: {result3}")
